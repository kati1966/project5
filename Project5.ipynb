# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('co2.csv')

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1', data=df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(9, 9))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x= df.drop("out1", axis=1)
#x = x.drop("engine", axis=1)
#x = x.drop("cylandr", axis=1)
y = df.out1

# %%
x
# Out:
#      engine  cylandr  fuelcomb
# 0       2.0        4       8.5
# 1       2.4        4       9.6
# 2       1.5        4       5.9
# 3       3.5        6      11.1
# 4       3.5        6      10.6
# ..      ...      ...       ...
# 495     1.5        4       6.9
# 496     1.5        4       7.5
# 497     1.5        4       7.7
# 498     3.5        6      10.6
# 499     3.6        6      10.8
#
# [500 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test= train_test_split(x, y, test_size=0.2)

# %%
X_test
# Out:
#      engine  cylandr  fuelcomb
# 32      4.0        8      11.3
# 345     5.4        8      17.2
# 415     2.0        4       5.5
# 354     3.5        6      11.5
# 246     6.2        8      14.3
# ..      ...      ...       ...
# 469     5.3        8      13.8
# 72      6.0       12      16.5
# 372     3.5        6      13.8
# 439     5.3        8      16.5
# 419     5.0        8      12.7
#
# [100 rows x 3 columns]

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
out_robot = model.predict(X_test)

# %%
out_robot
# Out:
# array([283.35876124, 343.61981064, 176.93936741, 258.58124921,
#        334.40494793, 248.94132489, 313.01622817, 206.86778238,
#        312.50779793, 368.00099056, 253.6883395 , 184.72052651,
#        252.99232985, 255.79721061, 337.37656594, 321.43087045,
#        184.02451686, 262.01961315, 267.60853251, 192.25157972,
#        228.06103537, 251.60031055, 188.20057476, 197.81965693,
#        294.60701378, 186.11254581, 189.55090975, 184.72052651,
#        188.89658441, 306.56423078, 269.02139397, 257.86439741,
#        322.25193304, 188.8549001 , 306.24371108, 197.12364728,
#        316.62132937, 280.13670622, 288.48882203, 255.77636845,
#        330.64573316, 208.25980168, 228.06103537, 372.17704846,
#        350.6007493 , 269.00055181, 343.48687035, 197.90302555,
#        388.69370067, 377.96683317, 182.63249755, 317.10891745,
#        321.28497535, 364.36715986, 248.14110446, 267.60853251,
#        254.50940209, 257.98945034, 298.58760492, 185.41653616,
#        294.60701378, 207.48042341, 328.24507186, 249.63733454,
#        333.66725397, 210.26446201, 378.64200066, 298.58760492,
#        292.66487993, 325.69029698, 298.58760492, 204.6963848 ,
#        186.11254581, 208.17643306, 186.07086149, 209.65182098,
#        210.34783063, 251.60031055, 368.00099056, 318.58430538,
#        250.9043009 , 198.51566658, 296.12408602, 181.24047825,
#        188.07552182, 213.74451026, 247.54930559, 199.29504485,
#        212.3316488 , 291.71087705, 201.29970518, 188.77153147,
#        230.14906433, 257.86439741, 208.95581133, 318.58430538,
#        385.60209717, 274.58947117, 337.37656594, 306.81466779])

# %%
X_test.engine[0]
# Out:
# np.float64(2.0)

# %%
y_test
# Out:
# 32     265
# 345    396
# 415    126
# 354    264
# 246    329
#       ...
# 469    317
# 72     380
# 372    317
# 439    380
# 419    292
# Name: out1, Length: 100, dtype: int64

# %%
X_test.cylandr
# Out:
# 32      8
# 345     8
# 415     4
# 354     6
# 246     8
#        ..
# 469     8
# 72     12
# 372     6
# 439     8
# 419     8
# Name: cylandr, Length: 100, dtype: int64

# %%
plt.scatter(X_test.engine, y_test, color='blue')
plt.show()

# %%
plt.scatter(X_test.engine, y_test, color='blue')
plt.scatter(X_test.fuelcomb, y_test, color='green')
plt.scatter(X_test.cylandr, y_test, color='red')
plt.show()

# %%
plt.scatter(X_test.engine, y_test, color = 'blue')
plt.show()

# %%
p206 =np.array([[5.2, 10, 114.8]])

# %%
co2=model.predict(p206)
# Out:
# C:\Users\kati\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
co2
# Out:
# array([1039.49652081])

# %%
sm.mean_squared_error(y_test, out_robot)
# Out:
# 605.3462758087
